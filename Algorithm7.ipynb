# %%
# The Algorithm7Main function efficiently sorts the input array A using counting sort
import unittest # import the unittest module
import time # import time function


  

def Algorithm7(A):
  N = len(A)
  max_value = max(A)  # Find the maximum value in A
  B = [0] * (max_value + 1)  # Create an auxiliary array B

  # Count frequencies of each element in A
  for value in A:
    B[value] += 1

  # Reconstruct the sorted array A using the counts in B
  index = 0
  for j in range(max_value + 1):
    for k in range(B[j]):
      A[index] = j
      index += 1

class TestAlgorithm2(unittest.TestCase):
    
    def read_array_from_file(self, filename):
        with open(filename, 'r') as file:
            lines = file.readlines()
            return [int(num) for line in lines for num in line.split()]

    def measure_runtime(self, A):
        start_time = time.time()
        Algorithm7(A)
        end_time = time.time()
        return end_time - start_time

    def compute_statistics(self, runtimes):
        min_time = min(runtimes)
        max_time = max(runtimes)
        avg_time = sum(runtimes) / len(runtimes)
        return min_time, avg_time, max_time

    def test_duplicate_array(self):
        # test_cases = ['duplicate_array_10.txt', 'duplicate_array_20.txt', 'duplicate_array_30.txt', 'duplicate_array_40.txt', 'duplicate_array_50.txt']
        test_cases = ['duplicate_array_3.txt', 'duplicate_array_8.txt', 'duplicate_array_10.txt', 'duplicate_array_13.txt', 'duplicate_array_15.txt']
        runtimes = []

        for filename in test_cases:
            A = self.read_array_from_file(filename)
            runtime = self.measure_runtime(A)
            runtimes.append(runtime)
            print(f"\n\nRuntime for duplicate array (N = {len(A)}): {runtime} seconds")

        min_time, avg_time, max_time = self.compute_statistics(runtimes)
        print(f"\nBest time: {min_time} seconds")
        print(f"Average time: {avg_time} seconds")
        print(f"Worst time: {max_time} seconds\n")

    def test_reverse_sorted_array(self):
        print("\nRunning tests on reverse-sorted array...")
        test_cases = ['reverse_sorted_array_3.txt', 'reverse_sorted_array_8.txt', 'reverse_sorted_array_10.txt', 'reverse_sorted_array_13.txt', 'reverse_sorted_array_15.txt']
        runtimes = []

        for filename in test_cases:
            A = self.read_array_from_file(filename)
            runtime = self.measure_runtime(A)
            runtimes.append(runtime)
            print(f"\n\nRuntime for reverse_sorted_array (N = {len(A)}): {runtime} seconds")

        min_time, avg_time, max_time = self.compute_statistics(runtimes)
        print(f"\nBest time: {min_time} seconds")
        print(f"Average time: {avg_time} seconds")
        print(f"Worst time: {max_time} seconds\n")

    def test_sorted_array(self):
        print("\nRunning tests on sorted array...")
        test_cases = ['sorted_array_3.txt', 'sorted_array_8.txt', 'sorted_array_10.txt', 'sorted_array_13.txt', 'sorted_array_15.txt']
        runtimes = []

        for filename in test_cases:
            A = self.read_array_from_file(filename)
            runtime = self.measure_runtime(A)
            runtimes.append(runtime)
            print(f"\n\nRuntime for sorted_array (N = {len(A)}): {runtime} seconds")

        min_time, avg_time, max_time = self.compute_statistics(runtimes)
        print(f"\nBest time: {min_time} seconds")
        print(f"Average time: {avg_time} seconds")
        print(f"Worst time: {max_time} seconds\n")

    def test_random_array(self):
        print("\nRunning tests on random array...")
        test_cases = ['random_array_3.txt', 'random_array_8.txt', 'random_array_10.txt', 'random_array_13.txt', 'random_array_15.txt']
        runtimes = []

        for filename in test_cases:
            A = self.read_array_from_file(filename)
            runtime = self.measure_runtime(A)
            runtimes.append(runtime)
            print(f"\n\nRuntime for random_array (N = {len(A)}): {runtime} seconds")

        min_time, avg_time, max_time = self.compute_statistics(runtimes)
        print(f"\nBest time: {min_time} seconds")
        print(f"Average time: {avg_time} seconds")
        print(f"Worst time: {max_time} seconds\n")

if __name__ == '__main__':
    unittest.main(argv=[''], exit=False)
# Out:
# ....
# Runtime for duplicate array (N = 3): 2.7179718017578125e-05 seconds
#
#
# Runtime for duplicate array (N = 8): 3.218650817871094e-05 seconds
#
#
# Runtime for duplicate array (N = 10): 3.0994415283203125e-05 seconds
#
#
# Runtime for duplicate array (N = 13): 3.4809112548828125e-05 seconds
#
#
# Runtime for duplicate array (N = 15): 3.600120544433594e-05 seconds
#
# Best time: 2.7179718017578125e-05 seconds
# Average time: 3.223419189453125e-05 seconds
# Worst time: 3.600120544433594e-05 seconds
#
#
# Running tests on random array...
#
#
# Runtime for random_array (N = 3): 0.0023050308227539062 seconds
#
#
# Runtime for random_array (N = 8): 0.00251007080078125 seconds
#
#
# Runtime for random_array (N = 10): 0.0027501583099365234 seconds
#
#
# Runtime for random_array (N = 13): 0.002849578857421875 seconds
#
#
# Runtime for random_array (N = 15): 0.0023610591888427734 seconds
#
# Best time: 0.0023050308227539062 seconds
# Average time: 0.002555179595947266 seconds
# Worst time: 0.002849578857421875 seconds
#
#
# Running tests on reverse-sorted array...
#
#
# Runtime for reverse_sorted_array (N = 3): 1.0728836059570312e-05 seconds
#
#
# Runtime for reverse_sorted_array (N = 8): 1.0967254638671875e-05 seconds
#
#
# Runtime for reverse_sorted_array (N = 10): 2.002716064453125e-05 seconds
#
#
# Runtime for reverse_sorted_array (N = 13): 1.3828277587890625e-05 seconds
#
#
# Runtime for reverse_sorted_array (N = 15): 2.4080276489257812e-05 seconds
#
# Best time: 1.0728836059570312e-05 seconds
# Average time: 1.5926361083984374e-05 seconds
# Worst time: 2.4080276489257812e-05 seconds
#
#
# Running tests on sorted array...
#
#
# Runtime for sorted_array (N = 3): 1.0013580322265625e-05 seconds
#
#
# Runtime for sorted_array (N = 8): 1.0967254638671875e-05 seconds
#
#
# Runtime for sorted_array (N = 10): 1.0967254638671875e-05 seconds
#
#
# Runtime for sorted_array (N = 13): 1.4066696166992188e-05 seconds
#
#
# Runtime for sorted_array (N = 15): 1.5020370483398438e-05 seconds
#
# Best time: 1.0013580322265625e-05 seconds
# Average time: 1.220703125e-05 seconds
# Worst time: 1.5020370483398438e-05 seconds
# ----------------------------------------------------------------------
# Ran 4 tests in 0.030s
#
# OK
